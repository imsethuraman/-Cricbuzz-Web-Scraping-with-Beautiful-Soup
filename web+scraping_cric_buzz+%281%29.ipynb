# %% [markdown]
# <h1><center>Web Scraping Cricbuzz</center><h1>

# %%
! pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\sethu\appdata\local\programs\python\python311\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sethu\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (2.4.1)

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\sethu\appdata\local\programs\python\python311\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sethu\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sethu\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sethu\appdata\local\programs\python\python311\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sethu\appdata\local\programs\python\python311\lib\site-packages (from requests) (2023.5.7)

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
        
    page=requests.get('https://www.cricbuzz.com/')                            
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()      
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)     
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta charset="utf-8"/><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>html{scroll-behavior: smooth;}	body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-30 {width:30%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb-col-65 {width:65%;}	.cb-col-66 {width:66%;}	.cb-col-67 {width:67%;}	.cb-col-73 {width:73%;}	.cb-col-75 {width:75%;}	.cb-col-70 {width:70%;}	.cb-col-84 {width:84%;}	.cb-col-80 {width:80%;}	.cb-col-90{width:90%;}	.cb-col-100 {width:100%;}	.cb-col {display: inline-block;box-sizing: border-box;float: left; min-height: 1px;}	h1 {font-size: 36px;line-height: 42px; margin:0;}	h2 {font-size: 24px; margin:0; line-height: 30px;}	h3 {font-size: 18px;line-height: 24px; margin:0; }	h4 {font-size: 16px; margin:0; }	h5 {font-size: 14px; margin: 0;}	.cb-font-18 {font-size:18px;}	img{border-radius: 4px;}	a {text-decoration: none; color:#222;}	a, a:hover, a:active, a:focus {outline: medium none;}	.text-center {text-align: center;}	.cb-nws-lft-col{padding:15px 20px;}	.cb-nws-dtl-lft-col {padding: 10px 30px 0 30px;border-right: 1px solid #ecebeb ;}	.cb-nws-lst-rt{padding-left: 10px;}	.cb-srs-lst-itm {padding: 10px 0;}	.cb-lst-itm-sm{padding:10px 0 5px;}	.cb-scrd-lft-col{padding:15px 10px;} .cb-col-rt{padding: 10px;}	.text-white{color: #fff;}	.cb-text-apple-red{color: #E90B37;}	.cb-color-light-sec{color: #464646;}	.cb-scrd-hdr-rw, .cb-nav-pill-1.active {background: #028062 ;color: #fff;}	.cb-nav{position:relative; height:48px;background: #009270;}	.cb-hm-mnu-itm{padding: 16px 6px 11px; color:#fff; display:inline-block;}	.cb-hm-text{padding:10px 18px 10px 20px;}	.cb-hm-rght{padding: 15px;}	.cb-subnav .cb-sub-navigation {display: none; position: absolute;}	.cb-mat-mnu{background:#4a4a4a; width:980px; font-size: 0;}	.cb-mat-mnu-itm{font-size:12px; color:#fff; padding:10px; cursor: pointer; display:inline-block; max-width: 140px;}	.cb-mat-mnu-ttl{background: #333; padding: 10px 20px;}	.cb-mat-mnu-wrp{margin-bottom: 10px;}	.cb-ovr-flo{overflow: hidden; white-space: nowrap; text-overflow: ellipsis;}	.cb-mat-mnu-all{text-align: center; float: right; width:60px;}	.cb-nav-main{border-bottom:1px solid #e3e6e3;padding:0 0 5px 20px;}	.cb-nav-bar{padding-top:10px;clear:both;}	.cb-lst-itm, .cb-bg-white{background: #fff;}	.cb-nav-tab.active, .cb-nav-tab-hm.active{ font-weight: bold; color: #028062;}	.cb-nav-tab.active {border-bottom: 3px solid #028062; line-height: 24px; }	.cb-nav-tab-hm.active{ border-bottom:2px solid #028062; line-height: 22px;}	.cb-nav-tab{margin-right:20px;padding-bottom:6px;}	.cb-nav-tab-hm{margin-right:15px;padding-bottom:6px;}	.cb-nav-hdr{padding-top:15px}	.cb-nav-subhdr{padding:5px 0 10px 0;}	.cb-lv-scr-mtch-hdr{line-height: 21px;font-size: 16px;}	.disp-none{display:none;}	.disp-blck{display:block;}	.cb-font-24{font-size: 24px;}	.line-ht30{line-height: 30px;}	.line-ht24{line-height: 24px;}	.cb-hm-scg-blk{background: #fff; margin-bottom: 5px; height:90px;}	.mrgn-btm-5{margin-bottom : 5px;}	#scagTabContent .show{display: block; visibility: visible;}	#scagTabContent .hide{display: none; visibility: hidden;}	[ng\:cloak], [ng-cloak], [data-ng-cloak], [x-ng-cloak], .ng-cloak, .x-ng-cloak { display: none !important;}	.cb-hm-lft{margin-bottom:5px;padding:0 15px;}	.cb-hm-lft-hd ...
# .cb-user-itm{position:absolute; top:0; right:5px}</style> </div> </div> <div class="cb-user-itm cb-subnav"> <a href="/premium-subscription/user/account-info" id="cb-plus-user-icon"><span class="cb-plus-ico cb-user-icon"></span></a> <nav class="cb-sub-navigation" id="cb-plus-dropdown" style="right:0px;"> <a class="cb-subnav-item" href="/premium-subscription/user/account-info" target="_self" title="My Account">My Account</a> <a class="cb-subnav-item" ng-click="sign_out_user(false)" target="_self" title="Sign Out">Sign Out</a></nav> </div></nav><style>.cb-text-link{color:#1866db;}
# .cb-plus-menu-button{padding: 8px 14px; background: #fff; border-radius: 18px; border: 0;}
# .cb-plus-menu-button:hover,.cb-plus-menu-button:focus, .cb-plus-menu-button:active{background: #fff;}</style></div></header><div class="page"><div id="fb-root"></div><div class="container" id="page-wrapper" style="display:inline-block;"><div class="ad-unit shosh-embed" id="shosh" style="height:0; width:980px; text-align:center;"></div><span class="ad-unit" id="skin_left" style="overflow:hidden; position:fixed;top:0;left:calc(50% - 635px);margin-right:3px;z-index:-99;"></span><div class="html-refresh" disable-first-load="true" timeout="300000" url="/api/html/matches-menu"><div class="cb-col cb-col-100 mrgn-btm-5"><nav class="cb-mat-mnu" ng-init="direction='up'"><a class="cb-mat-mnu-itm cb-ovr-flo cb-mat-mnu-ttl" href="/cricket-match/live-scores" id="live-scores-link" target="_self" title="">MATCHES</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/72819/wi-vs-ind-1st-test-india-tour-of-west-indies-2023" target="_self" title="West Indies v India, 1st Test - Stumps">WI vs IND - Stumps</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/73449/szone-vs-wzone-final-duleep-trophy-2023" target="_self" title="South Zone v West Zone, Final - Break">SZONE vs WZONE - Break</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/73407/indw-vs-banw-3rd-t20i-india-women-tour-of-bangladesh-2023" target="_self" title="India Women v Bangladesh Women, 3rd T20I - Complete">INDW vs BANW - Complete</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/59762/sus-vs-derby-county-div-2-county-championship-division-two-2023" target="_self" title="Sussex v Derbyshire, County Div 2 - Live">SUS vs DERBY - Live</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/69001/lkk-vs-nrk-final-tamil-nadu-premier-league-2023" target="_self" title="Lyca Kovai Kings v Nellai Royal Kings, Final - LKK Won">LKK vs NRK - LKK Won</a><span ng-click="(direction=='up')?direction = 'down' : direction = 'up'"><a class="cb-mat-mnu-itm cb-mat-mnu-all" id="match-dropdown" ng-class="{true:'cb-mat-mnu-cls'}[direction=='down']"><span ng-bind="(direction=='up') ? 'ALL': 'CLOSE'"></span><span ng-class="(direction=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></span></nav><div id="matchmenu"><div class="cb-mm-wrp {{direction}}"><div class="cb-scg-drp-dwn cb-col cb-col-100 cb-mnu-{{direction}}"><nav class="nav cb-mm-nvtb" ng-init="option= 'all'"><a class="cb-nav-pill-2 {{(option=='all')?'active':''}}" ng-click="option='all'" style="margin-right: 20px;">All</a><a class="cb-nav-pill-2 {{(option=='live')?'active':''}}" ng-click="option='live'" style="margin-right: 20px;">Live Now</a><a class="cb-nav-pill-2 {{(option=='today')?'active':''}}" ng-click="option='today'" style="margin-right: 20px;">Today</a></nav><style>.cb-nt-{{option}}{opacity:0.4!important;}</style><ul class="cb-scg-drp-dwn-ul"><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mm-typ">INTERNATIONAL</div><div class="cb-scg-srs-nm">India tour of WI, 2023</div><div class="cb-mtch-all cb-nt-live"><a href="/live-cricket-scores/72819/wi-vs-ind-1st-test-india-tour-of-wi-2023" target="_self" title="West Indies v India, 1st Test - Stumps"><span class="cb-mm-mtch-tm">West Indies vs India</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">1st Test</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-scg-srs-nm">Afghanistan tour of Bangladesh, 2023</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/71010/afg-vs-ban-3rd-odi-afghanistan-tour-of-bangladesh-2023" target="_self" title="Afghanistan v Bangladesh, 3rd ODI - BAN Won"><span class="cb-mm-mtch-tm">Afghanistan vs Bangladesh</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">3rd ODI</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/7 ...
# });</script> <div class="cb-col cb-hm-mid cb-bg-white cb-hmpage" style="clear:both"> <div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>WI VS IND, 1ST TEST</span></div><a href="/live-cricket-scores/72819/wi-vs-ind-1st-test" title="Ashwin, Jadeja and openers assert India's day of dominance"><img alt="Ashwin, Jadeja and openers assert India's day of dominance" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c334758/ashwin-jadeja-and-openers-ass.jpg" title="Ashwin, Jadeja and openers assert India's day of dominance" width="420"/></a><h2 class="big-crd-hdln"><a href="/live-cricket-scores/72819/wi-vs-ind-1st-test" title="Ashwin, Jadeja and openers assert India's day of dominance">	Ashwin, Jadeja and openers assert India's day of dominance</a></h2><div class="cb-nws-intr">The openers put on 80 after Ashwin bagged his 33rd fifer and Jadeja finished with three wickets</div><div class="cb-hm-mtch-crd-width cb-lv-scrs-well cb-lv-scrs-well-live"> <a href="/live-cricket-scores/72819/wi-vs-ind-1st-test-india-tour-of-west-indies-2023" title="WI Vs IND, 1st Test Live cricket scores"> <div class="cb-col cb-col-100 cb-hm-mtch-crd cb-pos-rel"> <div class="cb-scr-wll-chvrn cb-col-90"> <div class="cb-lv-scrs-col text-black"> <div class="cb-col cb-mr-30"> <div class="text-bold">IND</div> <div class="text-bold">WI</div> </div> <div class="cb-col"> <div> <span>80-0</span> <span> (23)</span> </div> <div> <span>150</span> </div> </div> </div> <div class="cb-lv-scrs-col cb-text-live" style="white-space:unset;">Day 1: Stumps - India trail by 70 runs</div> </div> <div class="cb-scr-wll-chvrn cb-col-10"> <div class="cb-ico cb-lv-scr-chvrn-bg"></div> </div> </div> </a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/127151/its-not-been-an-easy-journey-ashwin-reflects-after-another-milestone" title="'It's not been an easy journey': Ashwin reflects after another milestone">'It's not been an easy journey': Ashwin reflects after another milestone</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/127149/ashwin-bags-33rd-fifer" title="Ashwin bags 33rd fifer"><span class="cb-pretag">Day 1 report / </span>Ashwin bags 33rd fifer</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-gallery/5743/day-1-pictures" title="Day 1 Pictures"><span class="cb-pretag">Gallery / </span>Day 1 Pictures</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>SHADAB KHAN INTERVIEW </span></div><a href="/cricket-news/127144/eyeing-australia-tour-after-world-cup-for-test-comeback-shadab-khan" title="Eyeing Australia tour after World Cup for Test comeback - Shadab Khan"><img alt="Eyeing Australia tour after World Cup for Test comeback - Shadab Khan" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c334727/eyeing-australia-tour-after-wo.jpg" title="Eyeing Australia tour after World Cup for Test comeback - Shadab Khan" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/127144/eyeing-australia-tour-after-world-cup-for-test-comeback-shadab-khan" title="Eyeing Australia tour after World Cup for Test comeback - Shadab Khan">	Eyeing Australia tour after World Cup for Test comeback - Shadab Khan</a></h2><div class="cb-nws-intr">The leg-spinner has hailed Pakistan's team manager Rehan ul Haq for his creativity to uplift the players mentally</div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>2023 ASIA CUP</span></div><a href="/cricket-news/127141/zaka-ashraf-jay-shah-meet-green-flags-asia-cup-hybrid-model" title="Zaka Ashraf-Jay Shah meet green-flags Asia Cup hybrid model"><img alt="Zaka Ashraf-Jay Shah meet green-flags Asia Cup hybrid model" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c334718/zaka-ashraf-jay-shah-meet-gree.jpg" title="Zaka Ashraf-Jay Shah meet green-flags Asia Cup hybrid model" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricke ...

# %%
links
# Out:
# [<div class="cb-nws-intr">The openers put on 80 after Ashwin bagged his 33rd fifer and Jadeja finished with three wickets</div>,
#  <div class="cb-nws-intr">The leg-spinner has hailed Pakistan's team manager Rehan ul Haq for his creativity to uplift the players mentally</div>,
#  <div class="cb-nws-intr">With all the boxes ticked, the schedule for the Asia Cup is expected to be released on Friday</div>,
#  <div class="cb-nws-intr">England have drawn level with Australia on points In the multi-format series after winning the first ODI by 2 wickets</div>,
#  <div class="cb-nws-intr">For a change, Stokes wasn't the one doing it for England in the middle. He instead sat back in the dressing room balcony and doodled his favourite characters from Dragon Ball Z</div>,
#  <div class="cb-nws-intr">The proposals to impose restrictions on the participation of international cricketers in T20 leagues did not receive majority approval at the meeting held in Durban on Tuesday</div>,
#  <div class="cb-nws-intr">In a series of recommendations to the International Cricket Council (ICC), the WCC has urged the world body to ensure an equitable schedule of matches for all full member countries</div>,
#  <div class="cb-nws-intr">The schedule for the ninth edition, announced by Cricket Australia, will have 59 games played between October 19 and December 2</div>,
#  <div class="cb-nws-intr">The keeper-bat replaces Georgia Redmayne</div>,
#  <div class="cb-nws-intr">Whether Tamim Iqbal's retirement reversal means he resumes his role as captain remains to be seen </div>,
#  <div class="cb-nws-intr">TSK signed experienced pros like Juan Theron and Imran Tahir ahead of the inaugural season of the MLC</div>,
#  <div class="cb-nws-intr">Marcus Stoinis, Matthew Wade, Shadab Khan and Haris Rauf bring excellent T20 pedigree for the Unicorns</div>,
#  <div class="cb-nws-intr">"It feels like my blood feels blue, I'll run through a wall for them," the 20-year-old prodigy tells as he braces up for a new T20 challenge</div>,
#  <div class="cb-nws-intr">Hosts chase down 140 in 14.3 overs without losing a wicket</div>,
#  <div class="cb-nws-intr">The hosts choked Afghanistan, keeping them to 126, before the batters strolled to an easy win</div>,
#  <div class="cb-nws-intr">A poor batting performance saw India get restricted to just 102/9 in their 20 overs</div>,
#  <div class="cb-nws-intr">Elsewhere, twin four-wicket hauls by Oliver Hannon-Dalby powered Warwickshire to an innings victory against Kent</div>,
#  <div class="cb-nws-intr">News bytes that you may have otherwise missed</div>,
#  <div class="cb-nws-intr">In a typically straight-talking interview with Cricbuzz, Jason Holder explains why nobody outside of the Big Three could take England's positive approach to Test cricket, and why the longest format is in its autumn years</div>,
#  <div class="cb-nws-intr">Australia's famous victory at The Oval was bookended by two outstanding performances from Head and Boland, both fascinating subplots in the success story of Australia under Pat Cummins</div>,
#  <div class="cb-nws-intr">Boundary hitting is the order of the day in the IPL especially after the introduction of the Impact Player rule and RCB will have to make rapid strides in this department to ensure they don't get left behind</div>,
#  <div class="cb-nws-intr">Free agency in women's cricket is far less common than in the men's game, but change is coming - particularly with a women's IPL looming into view</div>,
#  <div class="cb-nws-intr">Aashish Kapoor's tale of scouting the young and prodigious left-arm wrist spinner, convincing Nehra to punt on him at last year's auction and reaping the subsequent dividends this season</div>,
#  <div class="cb-nws-intr">The former India bowling coach talks about the team's preparations for England, what changed between the 2018 and 2021 tours, his coaching philosophy and more</div>,
#  <div class="cb-nws-intr">When New Zealand pulled out of a tour in September, Pakistan's players were devastated. Yet the emotion has been channelled into a momentous T20 World Cup campaign, with Babar Azam proving an authoritative new leader</div>]

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# The openers put on 80 after Ashwin bagged his 33rd fifer and Jadeja finished with three wickets
#
#
# The leg-spinner has hailed Pakistan's team manager Rehan ul Haq for his creativity to uplift the players mentally
#
#
# With all the boxes ticked, the schedule for the Asia Cup is expected to be released on Friday
#
#
# England have drawn level with Australia on points In the multi-format series after winning the first ODI by 2 wickets
#
#
# For a change, Stokes wasn't the one doing it for England in the middle. He instead sat back in the dressing room balcony and doodled his favourite characters from Dragon Ball Z
#
#
# The proposals to impose restrictions on the participation of international cricketers in T20 leagues did not receive majority approval at the meeting held in Durban on Tuesday
#
#
# In a series of recommendations to the International Cricket Council (ICC), the WCC has urged the world body to ensure an equitable schedule of matches for all full member countries
#
#
# The schedule for the ninth edition, announced by Cricket Australia, will have 59 games played between October 19 and December 2
#
#
# The keeper-bat replaces Georgia Redmayne
#
#
# Whether Tamim Iqbal's retirement reversal means he resumes his role as captain remains to be seen
#
#
# TSK signed experienced pros like Juan Theron and Imran Tahir ahead of the inaugural season of the MLC
#
#
# Marcus Stoinis, Matthew Wade, Shadab Khan and Haris Rauf bring excellent T20 pedigree for the Unicorns
#
#
# "It feels like my blood feels blue, I'll run through a wall for them," the 20-year-old prodigy tells as he braces up for a new T20 challenge
#
#
# Hosts chase down 140 in 14.3 overs without losing a wicket
#
#
# The hosts choked Afghanistan, keeping them to 126, before the batters strolled to an easy win
#
#
# A poor batting performance saw India get restricted to just 102/9 in their 20 overs
#
#
# Elsewhere, twin four-wicket hauls by Oliver Hannon-Dalby powered Warwickshire to an innings victory against Kent
#
#
# News bytes that you may have otherwise missed
#
#
# In a typically straight-talking interview with Cricbuzz, Jason Holder explains why nobody outside of the Big Three could take England's positive approach to Test cricket, and why the longest format is in its autumn years
#
#
# Australia's famous victory at The Oval was bookended by two outstanding performances from Head and Boland, both fascinating subplots in the success story of Australia under Pat Cummins
#
#
# Boundary hitting is the order of the day in the IPL especially after the introduction of the Impact Player rule and RCB will have to make rapid strides in this department to ensure they don't get left behind
#
#
# Free agency in women's cricket is far less common than in the men's game, but change is coming - particularly with a women's IPL looming into view
#
#
# Aashish Kapoor's tale of scouting the young and prodigious left-arm wrist spinner, convincing Nehra to punt on him at last year's auction and reaping the subsequent dividends this season
#
#
# The former India bowling coach talks about the team's preparations for England, what changed between the 2018 and 2021 tours, his coaching philosophy and more
#
#
# When New Zealand pulled out of a tour in September, Pakistan's players were devastated. Yet the emotion has been channelled into a momentous T20 World Cup campaign, with Babar Azam proving an authoritative new leader
